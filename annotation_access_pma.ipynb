# %%
pip install pma_python
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 10.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 9.3 MB/s eta 0:00:000m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 500.6/500.6 kB 6.9 MB/s eta 0:00:000:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 9.8 MB/s eta 0:00:000m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.4/140.4 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.2/160.2 kB 7.6 MB/s eta 0:00:00
# ...

# %%
from pma_python import core

# %%
server='https://caib.actrec.gov.in/core/'
user='medal.ee.iitb'
passward='4TF6A9SB'
sessionID= core.connect(server, user,passward)

# %%
print(sessionID)
# Out:
# k9VkyAbn6Avdb-mGMyrLwA2

# %%
dir= core.get_root_directories()

# %%
print(dir)
# Out:
# ['acobat', 'BRIGHT', 'CAMELYON', 'Lung_SCAN', 'MedAct', 'NodeData', 'ROI Clusters', 'ROI_Patches', 'TCGA_WSIS']

# %%
file=core.get_directories('TCGA_WSIS')

# %%
print(file)
# Out:
# ['TCGA_WSIS/acc', 'TCGA_WSIS/blca', 'TCGA_WSIS/brca', 'TCGA_WSIS/cesc', 'TCGA_WSIS/chol', 'TCGA_WSIS/coad', 'TCGA_WSIS/dlbc', 'TCGA_WSIS/esca', 'TCGA_WSIS/gbm', 'TCGA_WSIS/hnsc', 'TCGA_WSIS/kich', 'TCGA_WSIS/kirc', 'TCGA_WSIS/kirp', 'TCGA_WSIS/lgg', 'TCGA_WSIS/lihc', 'TCGA_WSIS/luad', 'TCGA_WSIS/lusc', 'TCGA_WSIS/meso', 'TCGA_WSIS/ov', 'TCGA_WSIS/paad', 'TCGA_WSIS/pcpg', 'TCGA_WSIS/prad', 'TCGA_WSIS/read', 'TCGA_WSIS/remaining', 'TCGA_WSIS/sarc', 'TCGA_WSIS/skcm', 'TCGA_WSIS/stad', 'TCGA_WSIS/tgct', 'TCGA_WSIS/thca', 'TCGA_WSIS/thym', 'TCGA_WSIS/ucec', 'TCGA_WSIS/ucs', 'TCGA_WSIS/uvm']

# %%
file=core.get_directories('TCGA_WSIS/luad')

# %%
file
# Out:
# ['TCGA_WSIS/luad/diagno', 'TCGA_WSIS/luad/tissue']

# %%
file=core.get_directories('TCGA_WSIS/luad/diagno')

# %%
file
# Out:
# []

# %%
file=core.get_slides('TCGA_WSIS/luad/diagno')

# %%
file
# Out:
# ['TCGA_WSIS/luad/diagno/TCGA-05-4244-01Z-00-DX1.d4ff32cd-38cf-40ea-8213-45c2b100ac01.svs',
#  'TCGA_WSIS/luad/diagno/TCGA-05-4245-01Z-00-DX1.36ff5403-d4bb-4415-b2c5-7c750d655cde.svs',
#  'TCGA_WSIS/luad/diagno/TCGA-05-4249-01Z-00-DX1.9fce0297-cc19-4c04-872c-4466ee4024db.svs',
#  'TCGA_WSIS/luad/diagno/TCGA-05-4250-01Z-00-DX1.90f67fdf-dff9-46ca-af71-0978d7c221ba.svs',
#  'TCGA_WSIS/luad/diagno/TCGA-05-4382-01Z-00-DX1.76b49a4c-dbbb-48b0-b677-6d3037e5ce88.svs',
#  'TCGA_WSIS/luad/diagno/TCGA-05-4384-01Z-00-DX1.CA68BF29-BBE3-4C8E-B48B-554431A9EE13.svs',
#  'TCGA_WSIS/luad/diagno/TCGA-05-4390-01Z-00-DX1.858E64DF-DD3E-4F43-B7C1-CE35B33F1C90.svs',
#  'TCGA_WSIS/luad/diagno/TCGA-05-4395-01Z-00-DX1.20205276-ca16-46b2-914a-fe5e576a5cf9.svs',
#  'TCGA_WSIS/luad/diagno/TCGA-05-4396-01Z-00-DX1.49DD5F68-7473-4945-B384-EA6D5AE383CB.svs',
#  'TCGA_WSIS/luad/diagno/TCGA-05-4397-01Z-00-DX1.00e9cdb3-b50e-439c-86b0-d7b73b802c0d.svs',
# ...

# %%
core.get_annotations(file[0])
# Out:
# [{'AnnotationID': 1182,
#   'AuditCreatedBy': 'raneswapnil82',
#   'AuditCreatedOn': '/Date(1661669290647+0530)/',
#   'AuditLastModifiedBy': None,
#   'AuditLastModifiedOn': None,
#   'Classification': 'Tumor',
#   'Color': 'rgba(148, 12, 10, 1)',
#   'Dimensions': 2,
#   'FillColor': 'rgba(0, 0, 0, 0)',
# ...
